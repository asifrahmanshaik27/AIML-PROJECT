# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Lenovo\OneDrive\Desktop\training\.venv\Scripts\Datasets\House_Prediction.csv")
print(df.head(10))
print(df.tail(10))
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
# 5  2014-05-02 00:00:00   490000.0       2.0       1.00          880      6380
# 6  2014-05-02 00:00:00   335000.0       2.0       2.00         1350      2560
# 7  2014-05-02 00:00:00   482000.0       4.0       2.50         2710     35868
# 8  2014-05-02 00:00:00   452500.0       3.0       2.50         2430     88426
# 9  2014-05-02 00:00:00   640000.0       4.0       2.00         1520      6200
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   str
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   str
#  15  city           4600 non-null   str
#  16  statezip       4600 non-null   str
#  17  country        4600 non-null   str
# ...

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='str')

# %%
df.shape
# Out:
# (4600, 18)

# %% [markdown]
# column wise data

# %%
df["price"].head(10)
# Out:
# 0     313000.0
# 1    2384000.0
# 2     342000.0
# 3     420000.0
# 4     550000.0
# 5     490000.0
# 6     335000.0
# 7     482000.0
# 8     452500.0
# 9     640000.0
# Name: price, dtype: float64

# %%
df["street"].tail(10)
# Out:
# 4590        13602 SE 186th Pl
# 4591       3529 SW Webster St
# 4592          37654 18th Pl S
# 4593    5703 Charlotte Ave SE
# 4594       26306 127th Ave SE
# 4595           501 N 143rd St
# 4596         14855 SE 10th Pl
# 4597         759 Ilwaco Pl NE
# 4598        5148 S Creston St
# 4599        18717 SE 258th St
# Name: street, dtype: str

# %%
df.groupby("country")["price"].mean()
# Out:
# country
# USA    551962.988473
# Name: price, dtype: float64

# %%
df.groupby("country")["price"].max()
# Out:
# country
# USA    26590000.0
# Name: price, dtype: float64

# %%
df.groupby("country")["price"].min()
# Out:
# country
# USA    0.0
# Name: price, dtype: float64

# %%
df.groupby("country")["price"].median()
# Out:
# country
# USA    460943.461539
# Name: price, dtype: float64

# %%
print(df.dtypes)
# Out:
# date                 str
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street               str
# city                 str
# statezip             str
# country              str
# dtype: object

# %%
df.sort_values("price").head(10)
# Out:
#                      date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 4567  2014-07-02 00:00:00    0.0       4.0       2.50         4080     18362
# 4588  2014-07-08 00:00:00    0.0       4.0       2.25         2890     18226
# 4542  2014-06-25 00:00:00    0.0       5.0       3.50         2640      6895
# 4374  2014-05-09 00:00:00    0.0       2.0       2.50         2200    188200
# 4358  2014-05-06 00:00:00    0.0       5.0       3.50         3480     36615
# 4357  2014-05-05 00:00:00    0.0       6.0       2.75         3200      9200
# 4356  2014-05-05 00:00:00    0.0       4.0       2.75         2600      5390
# 4354  2014-05-05 00:00:00    0.0       3.0       1.75         1490     10125
# 4394  2014-05-16 00:00:00    0.0       5.0       3.25         3690     12353
# 4405  2014-05-20 00:00:00    0.0       4.0       3.75         3300      4545
#
#       floors  waterfront  view  condition  sqft_above  sqft_basement  \
# ...

# %%
df.sort_values("price",ascending=False).head(10)
# Out:
#                      date       price  bedrooms  bathrooms  sqft_living  \
# 4350  2014-07-03 00:00:00  26590000.0       3.0       2.00         1180
# 4346  2014-06-23 00:00:00  12899000.0       3.0       2.50         2190
# 2286  2014-06-11 00:00:00   7062500.0       5.0       4.50        10040
# 2654  2014-06-17 00:00:00   4668000.0       5.0       6.75         9640
# 2761  2014-06-18 00:00:00   4489000.0       4.0       3.00         6430
# 3729  2014-07-01 00:00:00   3800000.0       5.0       5.50         7050
# 1637  2014-05-30 00:00:00   3710000.0       4.0       3.50         5550
# 252   2014-05-07 00:00:00   3200000.0       7.0       4.50         6210
# 1567  2014-05-29 00:00:00   3100000.0       6.0       4.25         6980
# 2772  2014-06-18 00:00:00   3000000.0       4.0       4.25         4850
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4350      7793     1.0           0     0          4        1180
# ...

# %%
high_price=df[df["price"]>200000]
print(high_price.head(3))
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0        1.5         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0        2.5         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0        2.0         1930     11947
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4595    False
# 4596    False
# 4597    False
# 4598    False
# 4599    False
# Length: 4600, dtype: bool

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100
print(missing_percentage)
# Out:
# date             0.0
# price            0.0
# bedrooms         0.0
# bathrooms        0.0
# sqft_living      0.0
# sqft_lot         0.0
# floors           0.0
# waterfront       0.0
# view             0.0
# condition        0.0
# sqft_above       0.0
# sqft_basement    0.0
# yr_built         0.0
# yr_renovated     0.0
# street           0.0
# city             0.0
# statezip         0.0
# country          0.0
# dtype: float64

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='str')

# %%
q1=df['price'].quantile(0.25)
q3=df["price"].quantile(0.75)
IQR=q3-q1
lower_limit=q1-1.5*IQR
upper_limit=q3+1.5*IQR
print("q1:",q1)
print('q3:',q3)
print("IQR:",IQR)
print("lower_limit:",lower_limit)
print("upper_limit:",upper_limit)
outliers=df[
    (df["price"]<lower_limit) |
    (df["price"]>upper_limit)
]
print("\n price Outliers:",len(outliers))
print("\nprice outliers:")
print(outliers[["date","price"]].head(20))
# Out:
# q1: 322875.0
# q3: 654962.5
# IQR: 332087.5
# lower_limit: -175256.25
# upper_limit: 1153093.75
#
#  price Outliers: 240
#
# price outliers:
#                     date      price
# 1    2014-05-02 00:00:00  2384000.0
# 11   2014-05-02 00:00:00  1400000.0
# 14   2014-05-02 00:00:00  1200000.0
# 99   2014-05-05 00:00:00  1395000.0
# 122  2014-05-05 00:00:00  2280000.0
# 133  2014-05-05 00:00:00  1425000.0
# 193  2014-05-06 00:00:00  1225000.0
# 201  2014-05-06 00:00:00  1580000.0
# 217  2014-05-06 00:00:00  1870000.0
# 227  2014-05-06 00:00:00  1800000.0
# 252  2014-05-07 00:00:00  3200000.0
# 284  2014-05-07 00:00:00  1500000.0
# 285  2014-05-07 00:00:00  1340000.0
# 309  2014-05-07 00:00:00  1532500.0
# 356  2014-05-08 00:00:00  1750000.0
# 359  2014-05-08 00:00:00  1500000.0
# 366  2014-05-08 00:00:00  1307000.0
# 373  2014-05-08 00:00:00  1250000.0
# 404  2014-05-09 00:00:00  2400000.0
# 414  2014-05-09 00:00:00  1370000.0

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.boxplot(df['price'])
plt.title("price before outlier treatment")
plt.ylabel("price")
plt.show()

# %%
df["price_capped"]=df["price"].clip(
    lower=lower_limit,
    upper=upper_limit
)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.boxplot(df['price_capped'])
plt.title("price after outlier treatment")
plt.ylabel("price")
plt.show()

# %%
import matplotlib.pyplot as plt
avg_price = df.groupby("bedrooms")['price'].mean()
plt.Figure(figsize=(7,5))
plt.bar(avg_price.index,
        avg_price.values,
        color = ['red','yellow'])
plt.title("AVerage of price by bedrooms")
plt.xlabel=("no of bedrooms")
plt.ylabel=("Average price")
plt.show()

# %%
import matplotlib.pyplot as plt
city_vs_sqft_living = df.groupby("city")["sqft_living"].mean()
print("\nAverage sqft_living by city:")
print(city_vs_sqft_living)
plt.Figure(figsize=(10,5))
plt.plot(
    city_vs_sqft_living.index,
    city_vs_sqft_living.values,
    marker="."
)

plt.title("Average charges by region")
plt.xlabel = ("city")
plt.ylabel = ("sqft_living")
plt.grid(True)
plt.show()
# Out:
# Average sqft_living by city:
# city
# Algona                 1608.600000
# Auburn                 2019.579545
# Beaux Arts Village     1490.000000
# Bellevue               2694.527972
# Black Diamond          1863.333333
# Bothell                2319.393939
# Burien                 1815.337838
# Carnation              2392.454545
# Clyde Hill             3620.909091
# Covington              1792.558140
# Des Moines             1812.620690
# Duvall                 2161.547619
# Enumclaw               1922.500000
# Fall City              2865.909091
# Federal Way            2054.114865
# Inglewood-Finn Hill    1520.000000
# Issaquah               2458.844920
# Kenmore                2110.530303
# Kent                   1981.270270
# Kirkland               2259.481283
# Lake Forest Park       2283.055556
# Maple Valley           2086.041667
# Medina                 4103.636364
# Mercer Island          3275.313953
# Milton                 1255.000000
# Newcastle              2689.090909
# ...

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='str')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
plt.scatter(df["sqft_living"], df["sqft_above"], color="green")

plt.title("sqft_living vs sqft_above")
plt.xlabel = ("sqft_living")
plt.ylabel = ("sqft_above")
plt.grid(True)

plt.show()

# %%
print("\nprice Statistics After Treatment:")
print(df["price"].describe())

plt.figure(figsize=(8, 5))

plt.hist(
    df["price"],
    bins=50
)

plt.title("price Distribution After Outlier Treatment")
plt.xlabel = ("price")
plt.ylabel = ("Frequency")

plt.show()
# Out:
# price Statistics After Treatment:
# count    4.600000e+03
# mean     5.519630e+05
# std      5.638347e+05
# min      0.000000e+00
# 25%      3.228750e+05
# 50%      4.609435e+05
# 75%      6.549625e+05
# max      2.659000e+07
# Name: price, dtype: float64

# %%
import matplotlib.pyplot as plt
avg_price = df.groupby("bedrooms")['price'].mean().sort_values(ascending=False)
top_price = avg_price.head(10)

plt.figure(figsize=(7,7))
plt.pie(top_price.values,
        labels=top_price.index.astype(str),
        autopct="%1.1f%%",
        startangle=90)

plt.title("Average price by Top 10 ")
plt.show()

# %%
df.sort_values("bedrooms",ascending=False)
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 241   2014-05-07 00:00:00   599999.0       9.0       4.50         3830
# 1500  2014-05-28 00:00:00  1970000.0       8.0       3.50         4440
# 3911  2014-07-03 00:00:00   340000.0       8.0       2.75         2790
# 1479  2014-05-28 00:00:00   565000.0       7.0       4.50         4140
# 1644  2014-05-30 00:00:00   840000.0       7.0       4.50         4290
# ...                   ...        ...       ...        ...          ...
# 3608  2014-06-27 00:00:00   516500.0       1.0       1.25         1100
# 4556  2014-06-27 00:00:00   167500.0       1.0       1.00          690
# 3778  2014-07-01 00:00:00   276000.0       1.0       0.75          370
# 2365  2014-06-12 00:00:00  1095000.0       0.0       0.00         3064
# 3209  2014-06-24 00:00:00  1295648.0       0.0       0.00         4810
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("House_Prediction.csv")
print("first 5 rows")
print(df.head())
print("\nlast 5 rows")
print(df.tail())
print(df.info())
print(df.describe())
print(df.shape)
df.hist(figsize=(10,8))
plt.title("feature distribution")
plt.show()
# Out:
# first 5 rows
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
import pandas as pd
import  matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("House_Prediction.csv")
corr_matrix=df.corr(numeric_only=True)
plt.figure(figsize=(10,8))
sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="Greens",
    fmt=".2f",
    linewidths=0.5
)
plt.title("correlation matrix heatmap")
plt.show()

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='str')

# %%
df.to_csv("preprocessed_data_2.csv",index=False)
print("saved")
# Out:
# saved

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df=pd.read_csv("preprocessed_data_2.csv")
df.head(5)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
X=df.drop("statezip",axis=1)
y=df["statezip"]
X=pd.get_dummies(X,drop_first=True)
X_train,X_test,y_train,y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
) 
print("Training Features:", X_train.shape)
print("Testing Features:", X_test.shape)
print("Training Features:", y_train.shape)
print("Testing Features:", y_test.shape)
print("Training Data")
print(X_train.head())
print("\nTesting Data")
print(X_test.head())
# Out:
# Training Features: (3680, 4649)
# Testing Features: (920, 4649)
# Training Features: (3680,)
# Testing Features: (920,)
# Training Data
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 1898   685000.0       4.0       2.50         2770     45514     2.0
# 1370   857000.0       4.0       3.00         3720     29043     2.0
# 3038   675000.0       4.0       2.50         2810     11120     2.0
# 2361  1485000.0       4.0       3.75         4030     10800     2.0
# 156    561000.0       3.0       2.00         2000      7000     2.0
#
#       waterfront  view  condition  sqft_above  ...  city_SeaTac  city_Seattle  \
# 1898           0     0          4        2770  ...        False         False
# 1370           0     0          3        3720  ...        False         False
# 3038           0     0          3        2810  ...        False         False
# 2361           0     0          3        4030  ...        False         False
# ...
