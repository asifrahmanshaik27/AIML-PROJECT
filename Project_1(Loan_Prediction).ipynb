# %% [markdown]
# importing dataset

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Lenovo\OneDrive\Desktop\training\.venv\Scripts\Datasets\Loan.csv")
print(df.head(3))
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %% [markdown]
# seeing all column names

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='str')

# %% [markdown]
# printing specific column

# %%
df["LoanAmount"].head(5)
# Out:
# 0      NaN
# 1    128.0
# 2     66.0
# 3    120.0
# 4    141.0
# Name: LoanAmount, dtype: float64

# %%
df["Credit_History"].tail(5)
# Out:
# 609    1.0
# 610    1.0
# 611    1.0
# 612    1.0
# 613    0.0
# Name: Credit_History, dtype: float64

# %% [markdown]
# shape,describe,info

# %%
df.shape
# Out:
# (614, 13)

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.info
# Out:
# <bound method DataFrame.info of       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]>

# %% [markdown]
# datatypes

# %%
df.dtypes
# Out:
# Loan_ID                  str
# Gender                   str
# Married                  str
# Dependents               str
# Education                str
# Self_Employed            str
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area            str
# Loan_Status              str
# dtype: object

# %% [markdown]
# replacing column names

# %%
df.rename(columns={
    "Gender":"Sex"
})
# Out:
#       Loan_ID     Sex Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %% [markdown]
# group by

# %%
df.groupby("Gender")["LoanAmount"].mean()
# Out:
# Gender
# Female    126.697248
# Male      149.265957
# Name: LoanAmount, dtype: float64

# %% [markdown]
# aggregate function

# %%
df["LoanAmount"].mean()
# Out:
# np.float64(146.41216216216216)

# %%
df["LoanAmount"].mode()
# Out:
# 0    120.0
# Name: LoanAmount, dtype: float64

# %%
df["LoanAmount"].median()
# Out:
# np.float64(128.0)

# %%
df["LoanAmount"].std()
# Out:
# np.float64(85.58732523570545)

# %%
df["LoanAmount"].var()
# Out:
# np.float64(7325.190241002422)

# %% [markdown]
# checking empty or null values

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 609    False
# 610    False
# 611    False
# 612    False
# 613    False
# Length: 614, dtype: bool

# %% [markdown]
# fixing null values

# %%
df['Gender'] = df['Gender'].fillna("Male")

# %%
df['Married'] = df['Married'].fillna("Yes")

# %%
df['Dependents'] = df['Dependents'].fillna(0)

# %%
df['Self_Employed'] = df['Self_Employed'].fillna("Yes")
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].mean())
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History'] = df['Credit_History'].fillna(1.0)

# %% [markdown]
# after fixing null values

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# correlation

# %%
import  matplotlib.pyplot as plt
import seaborn as sns
corr_matrix=df.corr(numeric_only=True)
plt.figure(figsize=(8,6))
sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="Greens",
    fmt=".2f",
    linewidths=0.5
)
plt.title("correlation matrix heatmap")
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.565620
# CoapplicantIncome        -0.116605           1.000000    0.187828
# LoanAmount                0.565620           0.187828    1.000000
# Loan_Amount_Term         -0.045242          -0.059675    0.038801
# Credit_History           -0.018615           0.011134   -0.001431
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.045242       -0.018615
# CoapplicantIncome         -0.059675        0.011134
# LoanAmount                 0.038801       -0.001431
# Loan_Amount_Term           1.000000        0.000432
# Credit_History             0.000432        1.000000

# %% [markdown]
# outlier

# %%
q1=df['LoanAmount'].quantile(0.25)
q3=df["LoanAmount"].quantile(0.75)
IQR=q3-q1
lower_limit=q1-1.5*IQR
upper_limit=q3+1.5*IQR
print("q1:",q1)
print('q3:',q3)
print("IQR:",IQR)
print("lower_limit:",lower_limit)
print("upper_limit:",upper_limit)
outliers=df[
    (df["LoanAmount"]<lower_limit) |
    (df["LoanAmount"]>upper_limit)
]
print("\n LoanAmount Outliers:",len(outliers))
print("\n LoanAmount outliers:")
print(outliers[["Loan_ID","LoanAmount"]].head(20))
# Out:
# q1: 100.25
# q3: 164.75
# IQR: 64.5
# lower_limit: 3.5
# upper_limit: 261.5
#
#  LoanAmount Outliers: 41
#
#  LoanAmount outliers:
#       Loan_ID  LoanAmount
# 5    LP001011       267.0
# 9    LP001020       349.0
# 21   LP001046       315.0
# 34   LP001100       320.0
# 54   LP001186       286.0
# 67   LP001233       312.0
# 83   LP001273       265.0
# 126  LP001448       370.0
# 130  LP001469       650.0
# 135  LP001488       290.0
# 155  LP001536       600.0
# 161  LP001562       275.0
# 171  LP001585       700.0
# 177  LP001610       495.0
# 233  LP001776       280.0
# 253  LP001843       279.0
# 258  LP001859       304.0
# 260  LP001865       330.0
# 278  LP001907       436.0
# 308  LP001996       480.0

# %%
plt.figure(figsize=(8,5))
plt.boxplot(df['LoanAmount'])
plt.title("LoanAmount before outlier treatment")
plt.ylabel("LoanAmount")
plt.show()

# %% [markdown]
# fixing outlier

# %%
df["LoanAmount_capped"]=df["LoanAmount"].clip(
    lower=lower_limit,
    upper=upper_limit
)

# %%
plt.figure(figsize=(8,5))
plt.boxplot(df['LoanAmount_capped'])
plt.title("LoanAmount after outlier treatment")
plt.ylabel("LoanAmount")
plt.show()

# %% [markdown]
# sort values

# %%
df.sort_values("LoanAmount")
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 568  LP002840  Female      No          0      Graduate            No
# 14   LP001030    Male     Yes          2      Graduate            No
# 133  LP001482    Male     Yes          0      Graduate           Yes
# 94   LP001325    Male      No          0  Not Graduate            No
# 555  LP002792    Male     Yes          1      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 369  LP002191    Male     Yes          0      Graduate            No
# 155  LP001536    Male     Yes         3+      Graduate            No
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 130  LP001469    Male      No          0      Graduate           Yes
# 171  LP001585    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 568             2378                0.0         9.0             360.0
# 14              1299             1086.0        17.0             120.0
# 133             3459                0.0        25.0             120.0
# 94              3620                0.0        25.0             120.0
# 555             5468             1032.0        26.0             360.0
# ..               ...                ...         ...               ...
# 369            19730             5266.0       570.0             360.0
# 155            39999                0.0       600.0             180.0
# 561            19484                0.0       600.0             360.0
# 130            20166                0.0       650.0             480.0
# 171            51763                0.0       700.0             300.0
#
#      Credit_History Property_Area Loan_Status  LoanAmount_capped
# 568             1.0         Urban           N                9.0
# 14              1.0         Urban           Y               17.0
# 133             1.0     Semiurban           Y               25.0
# 94              1.0     Semiurban           Y               25.0
# 555             1.0     Semiurban           Y               26.0
# ..              ...           ...         ...                ...
# 369             1.0         Rural           N              261.5
# 155             0.0     Semiurban           Y              261.5
# 561             1.0     Semiurban           Y              261.5
# 130             1.0         Urban           Y              261.5
# 171             1.0         Urban           Y              261.5
#
# [614 rows x 14 columns]

# %%
df.sort_values("Loan_Amount_Term",ascending=False)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 248  LP001824    Male     Yes          1      Graduate            No
# 75   LP001255    Male      No          0      Graduate            No
# 573  LP002862    Male     Yes          2  Not Graduate            No
# 130  LP001469    Male      No          0      Graduate           Yes
# 168  LP001579    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 242  LP001806    Male      No          0      Graduate            No
# 68   LP001238    Male     Yes         3+  Not Graduate           Yes
# 262  LP001870  Female      No          1      Graduate            No
# 546  LP002768    Male      No          0  Not Graduate            No
# 497  LP002588    Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 248             2882             1843.0       123.0             480.0
# 75              3750                0.0       113.0             480.0
# 573             6125             1625.0       187.0             480.0
# 130            20166                0.0       650.0             480.0
# 168             2237                0.0        63.0             480.0
# ..               ...                ...         ...               ...
# 242             2965             5701.0       155.0              60.0
# 68              7100                0.0       125.0              60.0
# 262             3481                0.0       155.0              36.0
# 546             3358                0.0        80.0              36.0
# 497             4625             2857.0       111.0              12.0
#
#      Credit_History Property_Area Loan_Status  LoanAmount_capped
# 248             1.0     Semiurban           Y              123.0
# 75              1.0         Urban           N              113.0
# 573             1.0     Semiurban           N              187.0
# 130             1.0         Urban           Y              261.5
# 168             0.0     Semiurban           N               63.0
# ..              ...           ...         ...                ...
# 242             1.0         Urban           Y              155.0
# 68              1.0         Urban           Y              125.0
# 262             1.0     Semiurban           N              155.0
# 546             1.0     Semiurban           N               80.0
# 497             1.0         Urban           Y              111.0
#
# [614 rows x 14 columns]

# %% [markdown]
# conditions

# %%
highest_amount=df[df["LoanAmount"]>150]
print(highest_amount.head(5))
# Out:
#      Loan_ID Gender Married Dependents Education Self_Employed  \
# 5   LP001011   Male     Yes          2  Graduate           Yes
# 7   LP001014   Male     Yes         3+  Graduate            No
# 8   LP001018   Male     Yes          2  Graduate            No
# 9   LP001020   Male     Yes          1  Graduate            No
# 12  LP001028   Male     Yes          2  Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 5              5417             4196.0       267.0             360.0
# 7              3036             2504.0       158.0             360.0
# 8              4006             1526.0       168.0             360.0
# 9             12841            10968.0       349.0             360.0
# 12             3073             8106.0       200.0             360.0
#
#     Credit_History Property_Area Loan_Status  LoanAmount_capped
# 5              1.0         Urban           Y              261.5
# 7              0.0     Semiurban           N              158.0
# 8              1.0         Urban           Y              168.0
# 9              1.0     Semiurban           N              261.5
# 12             1.0         Urban           Y              200.0

# %% [markdown]
# And &

# %%
filtered=df[(df["LoanAmount"]>200)&(df["Loan_Amount_Term"]<360)]
print(filtered.head(5))
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 155  LP001536   Male     Yes         3+      Graduate            No
# 171  LP001585   Male     Yes         3+      Graduate            No
# 253  LP001843   Male     Yes          1  Not Graduate            No
# 333  LP002101   Male     Yes          0      Graduate           Yes
# 372  LP002201   Male     Yes          2      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 155            39999                0.0       600.0             180.0
# 171            51763                0.0       700.0             300.0
# 253             2661             7101.0       279.0             180.0
# 333            63337                0.0       490.0             180.0
# 372             9323             7873.0       380.0             300.0
#
#      Credit_History Property_Area Loan_Status  LoanAmount_capped
# 155             0.0     Semiurban           Y              261.5
# 171             1.0         Urban           Y              261.5
# 253             1.0     Semiurban           Y              261.5
# 333             1.0         Urban           Y              261.5
# 372             1.0         Rural           Y              261.5

# %%
filtered=df[(df["LoanAmount"]>200)  | (df["Loan_Amount_Term"]<360)]
print(filtered.head(5))
# Out:
#      Loan_ID Gender Married Dependents     Education Self_Employed  \
# 5   LP001011   Male     Yes          2      Graduate           Yes
# 9   LP001020   Male     Yes          1      Graduate            No
# 14  LP001030   Male     Yes          2      Graduate            No
# 16  LP001034   Male      No          1  Not Graduate            No
# 19  LP001041   Male     Yes          0      Graduate           Yes
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 5              5417             4196.0       267.0             360.0
# 9             12841            10968.0       349.0             360.0
# 14             1299             1086.0        17.0             120.0
# 16             3596                0.0       100.0             240.0
# 19             2600             3500.0       115.0             342.0
#
#     Credit_History Property_Area Loan_Status  LoanAmount_capped
# 5              1.0         Urban           Y              261.5
# 9              1.0     Semiurban           N              261.5
# 14             1.0         Urban           Y               17.0
# 16             1.0         Urban           Y              100.0
# 19             1.0         Urban           Y              115.0

# %% [markdown]
# visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
gender=df.groupby("Gender")["LoanAmount"].mean()
plt.bar(gender.index,
        gender.values,
        color=["red","yellow"]
        )
plt.title("Gender Avg Loan amount")
plt.xlabel("Gender")
plt.ylabel("loan amount")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
gender=df.groupby("Gender")["LoanAmount"].count()
plt.Figure(figsize=(8,5))
plt.plot(gender.index,
        gender.values,
        marker=".")
plt.title("No.of people by gender")
plt.xlabel=("Gender")
plt.ylabel=("loan amount")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
plt.scatter(df["LoanAmount"], df["ApplicantIncome"], color="red")

plt.title("LoanAmount vs ApplicantIncome")
plt.xlabel = ("LoanAmount")
plt.ylabel = ("ApplicantIncome")
plt.grid(True)

plt.show()

# %%
print("\nLoanAmount Statistics After Treatment:")
print(df["LoanAmount"].describe())

plt.figure(figsize=(8, 5))

plt.hist(
    df["LoanAmount"],
    bins=50
)

plt.title(" loanamount Distribution After Outlier Treatment")
plt.xlabel = ("LoanAmount")
plt.ylabel = ("Frequency")

plt.show()
# Out:
# LoanAmount Statistics After Treatment:
# count    614.000000
# mean     146.412162
# std       84.037468
# min        9.000000
# 25%      100.250000
# 50%      129.000000
# 75%      164.750000
# max      700.000000
# Name: LoanAmount, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print("First 5 Rows:")
print(df.head())
print("\nLast 5 Rows:")
print(df.tail())
print("\nDataset Information:")
print(df.info())
print("\nStatistical Summary:")
print(df.describe())
print("\nShape of Dataset:")
print(df.shape)
df.hist(figsize=(12,6))
plt.title("Feature Distributions")
plt.show()
# Out:
# First 5 Rows:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status  LoanAmount_capped
# 0             1.0         Urban           Y         146.412162
# 1             1.0         Rural           N         128.000000
# 2             1.0         Urban           Y          66.000000
# 3             1.0         Urban           Y         120.000000
# 4             1.0         Urban           Y         141.000000
#
# Last 5 Rows:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status  LoanAmount_capped
# 609             1.0         Rural           Y               71.0
# 610             1.0         Rural           Y               40.0
# 611             1.0         Urban           Y              253.0
# 612             1.0         Urban           Y              187.0
# 613             0.0     Semiurban           N              133.0
#
# Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    str
#  1   Gender             614 non-null    str
#  2   Married            614 non-null    str
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    str
#  5   Self_Employed      614 non-null    str
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    str
#  12  Loan_Status        614 non-null    str
#  13  LoanAmount_capped  614 non-null    float64
# dtypes: float64(5), int64(1), object(1), str(7)
# memory usage: 67.3+ KB
# None
#
# Statistical Summary:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  146.412162        342.000000
# std        6109.041673        2926.248369   84.037468         64.372489
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  129.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History  LoanAmount_capped
# count      614.000000         614.000000
# mean         0.855049         138.025354
# std          0.352339          55.773951
# min          0.000000           9.000000
# 25%          1.000000         100.250000
# 50%          1.000000         129.000000
# 75%          1.000000         164.750000
# max          1.000000         261.500000
#
# Shape of Dataset:
# (614, 14)

# %%
import matplotlib.pyplot as plt
avg_amount = df.groupby("Gender")['LoanAmount'].mean().sort_values(ascending=False)
top_amount = avg_amount.head(10)

plt.figure(figsize=(7,7))
plt.pie(top_amount.values,
        labels=top_amount.index.astype(str),
        autopct="%1.1f%%",
        startangle=90)

plt.title("Average price by Top 10 ")
plt.show()

# %% [markdown]
# Train & Test

# %%
df.to_csv("preprocessed_data_1.csv",index=False)
print("saved")
# Out:
# saved

# %% [markdown]
# installing sklearn

# %%
! pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\Lenovo\OneDrive\Desktop\training\.venv\Lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\Lenovo\OneDrive\Desktop\training\.venv\Lib\site-packages (from scikit-learn) (2.5.1)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\Lenovo\OneDrive\Desktop\training\.venv\Lib\site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\Lenovo\OneDrive\Desktop\training\.venv\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\Lenovo\OneDrive\Desktop\training\.venv\Lib\site-packages (from scikit-learn) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\Lenovo\OneDrive\Desktop\training\.venv\Lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 26.1.2 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df=pd.read_csv("preprocessed_data_1.csv")
df.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status  LoanAmount_capped
# 0             1.0         Urban           Y         146.412162
# 1             1.0         Rural           N         128.000000
# 2             1.0         Urban           Y          66.000000
# 3             1.0         Urban           Y         120.000000
# 4             1.0         Urban           Y         141.000000

# %%
X=df.drop("LoanAmount",axis=1)
y=df["LoanAmount"]
X=pd.get_dummies(X,drop_first=True)
X_train,X_test,y_train,y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
) 
print("Training Features:", X_train.shape)
print("Testing Features:", X_test.shape)
print("Training Features:", y_train.shape)
print("Testing Features:", y_test.shape)
print("Training Data")
print(X_train.head())
print("\nTesting Data")
print(X_test.head())
# Out:
# Training Features: (491, 628)
# Testing Features: (123, 628)
# Training Features: (491,)
# Testing Features: (123,)
# Training Data
#      ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 83              6000             2250.0             360.0             1.0
# 90              2958             2900.0             360.0             1.0
# 227             6250             1695.0             360.0             1.0
# 482             2083             3150.0             360.0             1.0
# 464             4166                0.0             360.0             0.0
#
#      LoanAmount_capped  Loan_ID_LP001003  Loan_ID_LP001005  Loan_ID_LP001006  \
# 83               261.5             False             False             False
# 90               131.0             False             False             False
# 227              210.0             False             False             False
# 482              128.0             False             False             False
# 464               98.0             False             False             False
#
#      Loan_ID_LP001008  Loan_ID_LP001011  ...  Gender_Male  Married_Yes  \
# 83              False             False  ...         True         True
# 90              False             False  ...         True         True
# 227             False             False  ...         True         True
# 482             False             False  ...         True         True
# 464             False             False  ...         True        False
#
#      Dependents_1  Dependents_2  Dependents_3+  Education_Not Graduate  \
# 83          False         False          False                   False
# 90          False         False          False                   False
# 227         False          True          False                   False
# 482         False         False          False                   False
# 464         False         False          False                   False
#
#      Self_Employed_Yes  Property_Area_Semiurban  Property_Area_Urban  \
# 83               False                     True                False
# 90               False                     True                False
# 227              False                     True                False
# 482              False                     True                False
# 464              False                     True                False
#
#      Loan_Status_Y
# 83           False
# 90            True
# 227           True
# 482           True
# 464          False
#
# [5 rows x 628 columns]
#
# Testing Data
#      ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 350             9083                0.0             360.0             1.0
# 377             4310                0.0             360.0             1.0
# 163             4167             1447.0             360.0             1.0
# 609             2900                0.0             360.0             1.0
# 132             2718                0.0             360.0             1.0
#
#      LoanAmount_capped  Loan_ID_LP001003  Loan_ID_LP001005  Loan_ID_LP001006  \
# 350              228.0             False             False             False
# 377              130.0             False             False             False
# 163              158.0             False             False             False
# 609               71.0             False             False             False
# 132               70.0             False             False             False
#
#      Loan_ID_LP001008  Loan_ID_LP001011  ...  Gender_Male  Married_Yes  \
# 350             False             False  ...         True         True
# 377             False             False  ...         True         True
# 163             False             False  ...         True         True
# 609             False             False  ...        False        False
# 132             False             False  ...         True        False
#
#      Dependents_1  Dependents_2  Dependents_3+  Education_Not Graduate  \
# 350         False         False          False                   False
# 377         False         False          False                   False
# 163         False          True          False                   False
# 609         False         False          False                   False
# 132         False         False          False                   False
#
#      Self_Employed_Yes  Property_Area_Semiurban  Property_Area_Urban  \
# 350              False                     True                False
# 377              False                     True                False
# 163              False                    False                False
# 609              False                    False                False
# 132              False                     True                False
#
#      Loan_Status_Y
# 350           True
# 377           True
# 163           True
# 609           True
# 132           True
#
# [5 rows x 628 columns]
